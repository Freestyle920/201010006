# %% [markdown]
# #T-2 자신의 타임라인 가져오기

# %%
import oauth2 as oauth
import os

# %%
def getApiKey(keyPath):
    d=dict()
    f=open(keyPath,'r')
    for line in f.readlines():
        row=line.split('=')
        row0=row[0]
        d[row0]=row[1].strip()
    return d

# %%
keyPath=os.path.join(os.getcwd(), 'bigdata', 'twitterApi.properties')
key=getApiKey(keyPath)

# %%
import twitter
auth = twitter.oauth.OAuth(key['Access_Token'], key['Access_Token_Secret'], key['Consumer_Key'], key['Consumer_Secret'])
_client = twitter.Twitter(auth=auth)

# %%
timeline = _client.statuses.home_timeline()

# %%
from pymongo import MongoClient

# %%
_mclient=MongoClient()
_mclient['ds_Twitter']
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'ds_Twitter')

# %%
_db=_mclient.ds_Twitter
_col1=_db.home_timeline1
_col1
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'ds_Twitter'), u'home_timeline1')

# %%
import oauth2 as oauth
import json
import urllib
consumer=oauth.Consumer(key=key['Consumer_Key'], secret=key['Consumer_Secret'])
token=oauth.Token(key=key['Access_Token'], secret=key['Access_Token_Secret'])

# %%
client=oauth.Client(consumer, token)
url="https://api.twitter.com/1.1/statuses/home_timeline.json"
response, content=client.request(url)

# %%
home_timeline=json.loads(content)
print home_timeline
# Out:
# [{u'contributors': None, u'truncated': False, u'text': u'practice_2016.11.21', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 800359290737332224L, u'favorite_count': 0, u'source': u'<a href="https://developers.naver.com/appinfo?consumer_key=GpnTlsOHG95EN_ngVCII" rel="nofollow">Freestyle_minkyu</a>', u'retweeted': False, u'coordinates': None, u'entities': {u'symbols': [], u'user_mentions': [], u'hashtags': [], u'urls': []}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 0, u'id_str': u'800359290737332224', u'favorited': False, u'user': {u'follow_request_sent': False, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': True, u'id': 3602061145L, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png', u'verified': False, u'translator_type': u'none', u'profile_text_color': u'333333', u'profile_image_url_https': u'https://abs.twimg.com/sticky/default_profile_images/default_profile_4_normal.png', u'profile_sidebar_fill_color': u'DDEEF6', u'entities': {u'description': {u'urls': []}}, u'followers_count': 2, u'profile_sidebar_border_color': u'C0DEED', u'id_str': u'3602061145', u'profile_background_color': u'C0DEED', u'listed_count': 0, u'is_translation_enabled': False, u'utc_offset': None, u'statuses_count': 7, u'description': u'', u'friends_count': 3, u'location': u'', u'profile_link_color': u'1DA1F2', u'profile_image_url': u'http://abs.twimg.com/sticky/default_profile_images/default_profile_4_normal.png', u'following': False, u'geo_enabled': False, u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png', u'screen_name': u'Kyrix_Cexyr', u'lang': u'ko', u'profile_background_tile': False, u'favourites_count': 0, u'name': u'Minkyu', u'notifications': False, u'url': None, u'created_at': u'Fri Sep 18 06:02:37 +0000 2015', u'contributors_enabled': False, u'time_zone': None, u'protected': False, u'default_profile': True, u'is_translator': False}, u'geo': None, u'in_reply_to_user_id_str': None, u'lang': u'en', u'created_at': u'Sun Nov 20 15:24:59 +0000 2016', u'in_reply_to_status_id_str': None, u'place': None}, {u'contributors': None, u'truncated': False, u'text': u'Happy Birthday @Jeff_Locke! \n\nRetweet this to wish Jeff a Happy Birthday! #BuccoBirthdays https://t.co/2w8QgJmKuk', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 800345466118377472L, u'favorite_count': 107, u'source': u'<a href="http://adobe.com" rel="nofollow">Adobe\xae Social</a>', u'retweeted': False, u'coordinates': None, u'entities': {u'symbols': [], u'user_mentions': [{u'id': 36895138, u'indices': [15, 26], u'id_str': u'36895138', u'screen_name': u'Jeff_Locke', u'name': u'Jeff Locke'}], u'hashtags': [{u'indices': [74, 89], u'text': u'BuccoBirthdays'}], u'urls': [], u'media': [{u'expanded_url': u'https://twitter.com/Pirates/status/800345466118377472/photo/1', u'display_url': u'pic.twitter.com/2w8QgJmKuk', u'url': u'https://t.co/2w8QgJmKuk', u'media_url_https': u'https://pbs.twimg.com/media/Cxtl9TUVIAAuFh_.jpg', u'id_str': u'800345462620364800', u'sizes': {u'large': {u'h': 512, u'resize': u'fit', u'w': 899}, u'small': {u'h': 387, u'resize': u'fit', u'w': 680}, u'medium': {u'h': 512, u'resize': u'fit', u'w': 899}, u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}}, u'indices': [90, 113], u'type': u'photo', u'id': 800345462620364800L, u'media_url': u'http://pbs.twimg.com/media/Cxtl9TUVIAAuFh_.jpg'}]}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 72, u'id_str': u'800345466118377472', u'favorited': False, u'user': {u'follow_request_sent': False, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 37947138, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/597793736043565056/3FCkm-Hg.jpg', u'verified': True, u'translator_type': u'regular', u'profile_text_color': u ...

# %%
home_timeline = json.loads(content)

# %%
for tweet in home_timeline:
    print tweet['id'],tweet['text']
# Out:
# 800359290737332224 practice_2016.11.21
# 800345466118377472 Happy Birthday @Jeff_Locke!
#
# Retweet this to wish Jeff a Happy Birthday! #BuccoBirthdays https://t.co/2w8QgJmKuk
# 800050998408409089 RT @Pittblack_gold: I LOVE YOU GUYS @Pirates THANK YOU! 💛⚾ #BucNation https://t.co/PxdVIb6l6N
# 799994410511409155 Cora brings 'wealth of experience' to Bucs' staff.
#
# READ: https://t.co/4pDCK4zZjH https://t.co/Ei949Smbpb
# 799790047469899776 #LightUpNight in the Burgh. https://t.co/1KaJgYOt61
# 799765534791307264 Congrats @Lahaha86 @dillonerd and @jesss152, you won our Pirates social prize pack! #BucsFanFriday https://t.co/VBN9fdtxGI
# 799747723473944576 The Pirates have added RHP Clay Holmes to their 40-man bringing the total to 40 players on the current roster.
# READ… https://t.co/EQWTPvFKpm
# 799707516309356544 Meet Manny!
# Tomorrow from 4-5pm Manny Sanguillen will be at the Verona Get Go to meet fans and sign autographs. https://t.co/3eU0VDLXMp
# 799678256467349504 RT @JTaillon19: Thanks for all of the birthday love, my wonderful cyber friends!
# 799676299631542272 RETWEET THIS for your chance to win a Pirates social prize pack as part of today's #BucsFanFriday! https://t.co/N2HmSwAE0N
# 799674095747133440 We have a winner! 👏 #BucsFanFriday https://t.co/04ay3i1hnw
# 799663865084710912 We're here!
#
# Be the first to find us NOW at the Robinson Mall Food Court to win our #BucsFanFriday prize pack! https://t.co/5vWvoivRyj
# 799654352835072000 We're on our way to our #BucsFanFriday location... check our Snapchat for clues!
#
# 👻: Pirates
# 799635789214720000 Happy #BucsFanFriday!
#
# Stay tuned for clues to see where we'll be today with THIS prize pack including a Jameson… https://t.co/yEPVLrOpT3
# 799620690710118400 Happy Birthday @JTaillon19!
#
# Retweet this to wish Jameson a Happy Birthday! #BuccoBirthdays https://t.co/CAUjH3LsCC
# 799382879549542400 Tomorrow is another #BucsFanFriday!
#
# We'll be around with free stuff... let us know where we should stop! https://t.co/BNxEt1bRdU
# 799360249924726784 Bartee wants Bucs to be aggressive on bases.
#
# READ: https://t.co/QK2F5gq87H https://t.co/GwSq4zXQmm
# 799314934349774848 That time when Marte's day was made. 🌼 #PiratesTBT
#
# https://t.co/Yzc8oOSjYO https://t.co/dwRDfNzTio
# 799258317998538752 Happy Birthday Elias Diaz!
#
# Retweet this to wish Elias a Happy Birthday! #BuccoBirthdays https://t.co/6gO11GKEqj

# %%
print home_timeline[0]['created_at']
print home_timeline[0]['id']
# Out:
# Sun Nov 20 15:24:59 +0000 2016
# 800359290737332224
