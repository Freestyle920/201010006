# %%
# %%writefile p_web_data_8.py
import scrapy

class QuoteItem(scrapy.Item):
    text = scrapy.Field()
    author = scrapy.Field()

class QuotesSpider(scrapy.Spider):
    name = "quotes"
    start_urls = [
        'http://quotes.toscrape.com/page/1/',
    ]
    def parse(self, response):
        for quote in response.xpath('//div[@class="quote"]'):
            item = QuoteItem()
            item['text'] = quote.xpath('span[@class="text"]/text()').extract_first()
            item['author'] = quote.xpath('span/small/text()').extract_first()
            print "crawling ",item['author']
            yield item
        next_page = response.xpath('//li[@class="next"]/a/@href').extract_first()
        if next_page:
            next_page = response.urljoin(next_page)
            print "--> visiting ",next_page
            yield scrapy.Request(next_page, callback=self.parse)
# Out:
# Writing p_web_data_8.py

# %%
# !scrapy runspider src/ds_web_data_paging.py -o src/ds_web_data_paging.json -t json --logfile src/ds_web_data_paging.logfile
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Minkyu Kim\Anaconda2\Scripts\scrapy-script.py", line 6, in <module>
#     sys.exit(scrapy.cmdline.execute())
#   File "C:\Users\Minkyu Kim\Anaconda2\lib\site-packages\scrapy\cmdline.py", line 141, in execute
#     cmd.crawler_process = CrawlerProcess(settings)
#   File "C:\Users\Minkyu Kim\Anaconda2\lib\site-packages\scrapy\crawler.py", line 240, in __init__
#     configure_logging(self.settings)
#   File "C:\Users\Minkyu Kim\Anaconda2\lib\site-packages\scrapy\utils\log.py", line 100, in configure_logging
#     handler = _get_handler(settings)
#   File "C:\Users\Minkyu Kim\Anaconda2\lib\site-packages\scrapy\utils\log.py", line 109, in _get_handler
#     handler = logging.FileHandler(filename, encoding=encoding)
#   File "C:\Users\Minkyu Kim\Anaconda2\lib\logging\__init__.py", line 913, in __init__
#     StreamHandler.__init__(self, self._open())
#   File "C:\Users\Minkyu Kim\Anaconda2\lib\logging\__init__.py", line 945, in _open
# ...

# %%
 'text': u'\u201cWhen one door of happiness closes, another opens; bu
look so long at the closed door that we do not see the one which has
 for us.\u201d'}
('crawling', u'George Bernard Shaw')
2016-10-10 12:49:55 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/6/>
{'author': u'George Bernard Shaw',
 'text': u"\u201cLife isn't about finding yourself. Life is about cre
elf.\u201d"}
('--> visiting ', u'http://quotes.toscrape.com/page/7/')
2016-10-10 12:49:55 [scrapy] DEBUG: Crawled (200) <GET http://quotes.
m/page/7/> (referer: http://quotes.toscrape.com/page/6/)
('crawling', u'Charles Bukowski')
2016-10-10 12:49:55 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/7/>
{'author': u'Charles Bukowski',
 'text': u"\u201cThat's the problem with drinking, I thought, as I po
 a drink. If something bad happens you drink in an attempt to forget;
ng good happens you drink in order to celebrate; and if nothing happe
k to make something happen.\u201d"}
('crawling', u'Suzanne Collins')
2016-10-10 12:49:55 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/7/>
{'author': u'Suzanne Collins',
 'text': u'\u201cYou don\u2019t forget the face of the person who was
hope.\u201d'}
('crawling', u'Suzanne Collins')
2016-10-10 12:49:55 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/7/>
{'author': u'Suzanne Collins',
 'text': u"\u201cRemember, we're madly in love, so it's all right to
time you feel like it.\u201d"}
('crawling', u'C.S. Lewis')
2016-10-10 12:49:55 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/7/>
{'author': u'C.S. Lewis',
 'text': u'\u201cTo love at all is to be vulnerable. Love anything an
t will be wrung and possibly broken. If you want to make sure of keep
ct you must give it to no one, not even an animal. Wrap it carefully
hobbies and little luxuries; avoid all entanglements. Lock it up safe
ket or coffin of your selfishness. But in that casket, safe, dark, mo
irless, it will change. It will not be broken; it will become unbreak
etrable, irredeemable. To love is to be vulnerable.\u201d'}
('crawling', u'J.R.R. Tolkien')
2016-10-10 12:49:55 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/7/>
{'author': u'J.R.R. Tolkien',
 'text': u'\u201cNot all those who wander are lost.\u201d'}
('crawling', u'J.K. Rowling')
2016-10-10 12:49:55 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/7/>
{'author': u'J.K. Rowling',
 'text': u'\u201cDo not pity the dead, Harry. Pity the living, and, a
ose who live without love.\u201d'}
('crawling', u'Ernest Hemingway')
2016-10-10 12:49:55 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/7/>
{'author': u'Ernest Hemingway',
 'text': u'\u201cThere is nothing to writing. All you do is sit down
iter and bleed.\u201d'}
('crawling', u'Ralph Waldo Emerson')
2016-10-10 12:49:55 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/7/>
{'author': u'Ralph Waldo Emerson',
 'text': u'\u201cFinish each day and be done with it. You have done w
ld. Some blunders and absurdities no doubt crept in; forget them as s
can. Tomorrow is a new day. You shall begin it serenely and with too
it to be encumbered with your old nonsense.\u201d'}
('crawling', u'Mark Twain')
2016-10-10 12:49:55 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/7/>
{'author': u'Mark Twain',
 'text': u'\u201cI have never let my schooling interfere with my educ
d'}
('crawling', u'Dr. Seuss')
2016-10-10 12:49:55 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/7/>
{'author': u'Dr. Seuss',
 'text': u"\u201cI have heard there are troubles of more than one kin
e from ahead and some come from behind. But I've bought a big bat. I'
 you see. Now my troubles are going to have troubles with me!\u201d"}
('--> visiting ', u'http://quotes.toscrape.com/page/8/')
2016-10-10 12:49:56 [scrapy] DEBUG: Crawled (200) <GET http://quotes.
m/page/8/> (referer: http://quotes.toscrape.com/page/7/)
('crawling', u'Alfred Tennyson')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/8/>
{'author': u'Alfred Tennyson',
 'text': u'\u201cIf I had a flower for every time I thought of you...
k through my garden forever.\u201d'}
('crawling', u'Charles Bukowski')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/8/>
{'author': u'Charles Bukowski',
 'text': u'\u201cSome people never go crazy. What truly horrible live
 lead.\u201d'}
('crawling', u'Terry Pratchett')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/8/>
{'author': u'Terry Pratchett',
 'text': u'\u201cThe trouble with having an open mind, of course, is
 will insist on coming along and trying to put things in it.\u201d'}
('crawling', u'Dr. Seuss')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/8/>
{'author': u'Dr. Seuss',
 'text': u'\u201cThink left and think right and think low and think h
e thinks you can think up if only you try!\u201d'}
('crawling', u'J.D. Salinger')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/8/>
{'author': u'J.D. Salinger',
 'text': u"\u201cWhat really knocks me out is a book that, when you'r
reading it, you wish the author that wrote it was a terrific friend o
 you could call him up on the phone whenever you felt like it. That d
en much, though.\u201d"}
('crawling', u'George Carlin')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/8/>
{'author': u'George Carlin',
 'text': u'\u201cThe reason I talk to myself is because I\u2019m the
ose answers I accept.\u201d'}
('crawling', u'John Lennon')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/8/>
{'author': u'John Lennon',
 'text': u"\u201cYou may say I'm a dreamer, but I'm not the only one.
eday you'll join us. And the world will live as one.\u201d"}
('crawling', u'W.C. Fields')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/8/>
{'author': u'W.C. Fields',
 'text': u'\u201cI am free of all prejudice. I hate everyone equally.
('crawling', u'Ayn Rand')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/8/>
{'author': u'Ayn Rand',
 'text': u"\u201cThe question isn't who is going to let me; it's who
 stop me.\u201d"}
('crawling', u'Mark Twain')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/8/>
{'author': u'Mark Twain',
 'text': u"\u201c\u2032Classic\u2032 - a book which people praise and
.\u201d"}
('--> visiting ', u'http://quotes.toscrape.com/page/9/')
2016-10-10 12:49:56 [scrapy] DEBUG: Crawled (200) <GET http://quotes.
m/page/9/> (referer: http://quotes.toscrape.com/page/8/)
('crawling', u'Albert Einstein')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/9/>
{'author': u'Albert Einstein',
 'text': u'\u201cAnyone who has never made a mistake has never tried
w.\u201d'}
('crawling', u'Jane Austen')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/9/>
{'author': u'Jane Austen',
 'text': u"\u201cA lady's imagination is very rapid; it jumps from ad
 love, from love to matrimony in a moment.\u201d"}
('crawling', u'J.K. Rowling')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/9/>
{'author': u'J.K. Rowling',
 'text': u'\u201cRemember, if the time should come when you have to m
e between what is right and what is easy, remember what happened to a
s good, and kind, and brave, because he strayed across the path of Lo
t. Remember Cedric Diggory.\u201d'}
('crawling', u'Jane Austen')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/9/>
{'author': u'Jane Austen',
 'text': u'\u201cI declare after all there is no enjoyment like readi
h sooner one tires of any thing than of a book! -- When I have a hous
, I shall be miserable if I have not an excellent library.\u201d'}
('crawling', u'Jane Austen')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/9/>
{'author': u'Jane Austen',
 'text': u'\u201cThere are few people whom I really love, and still f
m I think well. The more I see of the world, the more am I dissatisfi
 and every day confirms my belief of the inconsistency of all human c
and of the little dependence that can be placed on the appearance of
nse.\u201d'}
('crawling', u'C.S. Lewis')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/9/>
{'author': u'C.S. Lewis',
 'text': u'\u201cSome day you will be old enough to start reading fai
ain.\u201d'}
('crawling', u'C.S. Lewis')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/9/>
{'author': u'C.S. Lewis',
 'text': u'\u201cWe are not necessarily doubting that God will do the
s; we are wondering how painful the best will turn out to be.\u201d'}
('crawling', u'Mark Twain')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/9/>
{'author': u'Mark Twain',
 'text': u'\u201cThe fear of death follows from the fear of life. A m
s fully is prepared to die at any time.\u201d'}
('crawling', u'Mark Twain')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/9/>
{'author': u'Mark Twain',
 'text': u'\u201cA lie can travel half way around the world while the
utting on its shoes.\u201d'}
('crawling', u'C.S. Lewis')
2016-10-10 12:49:56 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/9/>
{'author': u'C.S. Lewis',
 'text': u'\u201cI believe in Christianity as I believe that the sun
not only because I see it, but because by it I see everything else.\u
('--> visiting ', u'http://quotes.toscrape.com/page/10/')
2016-10-10 12:49:57 [scrapy] DEBUG: Crawled (200) <GET http://quotes.
m/page/10/> (referer: http://quotes.toscrape.com/page/9/)
('crawling', u'J.K. Rowling')
2016-10-10 12:49:57 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/10/>
{'author': u'J.K. Rowling',
 'text': u'\u201cThe truth." Dumbledore sighed. "It is a beautiful an
thing, and should therefore be treated with great caution.\u201d'}
('crawling', u'Jimi Hendrix')
2016-10-10 12:49:57 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/10/>
{'author': u'Jimi Hendrix',
 'text': u"\u201cI'm the one that's got to die when it's time for me
let me live my life the way I want to.\u201d"}
('crawling', u'J.M. Barrie')
2016-10-10 12:49:57 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/10/>
{'author': u'J.M. Barrie',
 'text': u'\u201cTo die will be an awfully big adventure.\u201d'}
('crawling', u'E.E. Cummings')
2016-10-10 12:49:57 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/10/>
{'author': u'E.E. Cummings',
 'text': u'\u201cIt takes courage to grow up and become who you reall
d'}
('crawling', u'Khaled Hosseini')
2016-10-10 12:49:57 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/10/>
{'author': u'Khaled Hosseini',
 'text': u'\u201cBut better to get hurt by the truth than comforted w
u201d'}
('crawling', u'Harper Lee')
2016-10-10 12:49:57 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/10/>
{'author': u'Harper Lee',
 'text': u'\u201cYou never really understand a person until you consi
from his point of view... Until you climb inside of his skin and walk
it.\u201d'}
('crawling', u"Madeleine L'Engle")
2016-10-10 12:49:57 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/10/>
{'author': u"Madeleine L'Engle",
 'text': u'\u201cYou have to write the book that wants to be written.
 book will be too difficult for grown-ups, then you write it for chil
'}
('crawling', u'Mark Twain')
2016-10-10 12:49:57 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/10/>
{'author': u'Mark Twain',
 'text': u'\u201cNever tell the truth to people who are not worthy of
}
('crawling', u'Dr. Seuss')
2016-10-10 12:49:57 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/10/>
{'author': u'Dr. Seuss',
 'text': u"\u201cA person's a person, no matter how small.\u201d"}
('crawling', u'George R.R. Martin')
2016-10-10 12:49:57 [scrapy] DEBUG: Scraped from <200 http://quotes.t
/page/10/>
{'author': u'George R.R. Martin',
 'text': u'\u201c... a mind needs books as a sword needs a whetstone,
o keep its edge.\u201d'}
2016-10-10 12:49:57 [scrapy] INFO: Closing spider (finished)
2016-10-10 12:49:57 [scrapy] INFO: Dumping Scrapy stats:
{'downloader/request_bytes': 2646,
 'downloader/request_count': 10,
 'downloader/request_method_count/GET': 10,
 'downloader/response_bytes': 24500,
 'downloader/response_count': 10,
 'downloader/response_status_count/200': 10,
 'finish_reason': 'finished',
 'finish_time': datetime.datetime(2016, 10, 10, 3, 49, 57, 590000),
 'item_scraped_count': 100,
 'log_count/DEBUG': 111,
 'log_count/INFO': 7,
 'request_depth_max': 9,
 'response_received_count': 10,
 'scheduler/dequeued': 10,
 'scheduler/dequeued/memory': 10,
 'scheduler/enqueued': 10,
 'scheduler/enqueued/memory': 10,
 'start_time': datetime.datetime(2016, 10, 10, 3, 49, 49, 665000)}
2016-10-10 12:49:57 [scrapy] INFO: Spider closed (finished)

(C:\Users\Minkyu Kim\Anaconda2) C:\Users\Minkyu Kim\Documents>^A
# Out:
#   File "<ipython-input-3-cd11f81cc1ea>", line 1
#     'text': u'\u201cWhen one door of happiness closes, another opens; bu
#           ^
# SyntaxError: invalid syntax
